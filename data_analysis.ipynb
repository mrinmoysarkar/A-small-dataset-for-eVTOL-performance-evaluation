# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import sys
sys.path.append('/media/ariac/DATAPART1/mrinmoys-document/eVTOL_performance_evaluation')
from performance_analysis import performanceanalyzer

# %%
pa = performanceanalyzer('/media/ariac/DATAPART1/mrinmoys-document/eVTOL_performance_evaluation/logs/example_run.json')
pa.load_data()
all_tj = pa.get_all_trajectories()
# Out:
# /media/ariac/DATAPART1/mrinmoys-document/eVTOL_performance_evaluation/performance_analysis.py:56: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (y1-y2)/(x1-x2)
# /media/ariac/DATAPART1/mrinmoys-document/eVTOL_performance_evaluation/performance_analysis.py:67: RuntimeWarning: invalid value encountered in double_scalars
#   err = abs(y2 - (m*x2+c))
# /media/ariac/DATAPART1/mrinmoys-document/eVTOL_performance_evaluation/performance_analysis.py:72: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (y1-y2)/(x1-x2)

# %%
all_tj[0][0]
# Out:
# array([3.47250000e+04, 6.01454643e+04, 2.25000000e+01, 3.89711432e+01,
#        3.60000000e+02])

# %%
plt.figure(figsize=(10,8))
for tj in all_tj:
    plt.plot(tj[:,0],tj[:,1])

# %%
plt.figure(figsize=(10,8))
for tj in all_tj:
    plt.scatter(tj[:,4], tj[:,2])

# %%
plt.figure(figsize=(10,8))
# for tj in all_tj:
plt.scatter(all_tj[5][:,4], all_tj[5][:,2])

# %%
plt.figure(figsize=(10,8))
# for tj in all_tj:
plt.scatter(all_tj[5][:,4], all_tj[5][:,3])

# %%
len(all_tj)
# Out:
# 1270
